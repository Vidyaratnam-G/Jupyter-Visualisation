# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = np.random.random((12, 12))
plt.imshow(data, cmap = "autumn", interpolation = "nearest")
plt.title("2-D Heatmap")
plt.show()

# %%
data = pd.read_csv(r'C:\Users\hemaa\Documents\Other\Ratnam\Blog\Hoops Hypothesis\Statistics.csv')
data
# Out:
#      Team  Points  ORebs  DRebs  Assists  Steals  Blocks  Turnovers  3Point%  \
# 0       1   118.1    6.1   29.5     27.3     8.4     2.0       15.7      0.3
# 1       2   120.5    6.5   29.9     27.3     9.1     2.4       13.5      0.3
# 2       3   118.1    6.5   32.0     29.1     8.4     2.1       14.1      0.3
# 3       4   117.2    7.2   33.3     29.1     8.1     2.4       14.3      0.3
# 4       5   115.7    7.6   33.3     27.3     8.0     2.0       14.3      0.3
# ..    ...     ...    ...    ...      ...     ...     ...        ...      ...
# 316   317   116.0    9.3   37.9     22.7     5.7     4.7       10.9      0.3
# 317   318   114.5    9.7   37.9     20.9     5.6     4.3       10.9      0.4
# 318   319   113.5   12.3   40.4     19.6     5.7     8.4       10.8      0.4
# 319   320   127.2   11.3   37.1     20.3     5.6     5.7       11.5      0.3
# 320   321   115.6    9.1   38.3     25.2     7.9     4.3       12.1      0.4
#
#      Free Throw%  Win-Coefficient
# ...

# %%
correlation = data.corr()
correlation
# Out:
#                      Team    Points     ORebs     DRebs   Assists    Steals  \
# Team             1.000000  0.038378  0.243757  0.526872  0.137807  0.046844
# Points           0.038378  1.000000 -0.084883 -0.355240  0.299646 -0.091320
# ORebs            0.243757 -0.084883  1.000000  0.791229 -0.369233 -0.062957
# DRebs            0.526872 -0.355240  0.791229  1.000000 -0.061861  0.043507
# Assists          0.137807  0.299646 -0.369233 -0.061861  1.000000  0.627649
# Steals           0.046844 -0.091320 -0.062957  0.043507  0.627649  1.000000
# Blocks           0.177080 -0.014859  0.849687  0.575894 -0.448490 -0.214748
# Turnovers        0.021784  0.350061 -0.166858 -0.115113  0.683025  0.461714
# 3Point%          0.013516 -0.499023 -0.073402 -0.017124 -0.221941  0.167753
# Free Throw%     -0.041059  0.151203 -0.357349 -0.259062  0.245577 -0.021121
# Win-Coefficient  0.447967  0.114702  0.298896  0.555727  0.736908  0.679440
#
# ...

# %%
columns = ["Team", "Points", "ORebs", "DRebs", "Assists", "Steals", "Blocks", "Turnovers", "3Point%", "FreeThrow%", "Win-Coefficient"]
plt.xticks(range(len(columns)),columns,rotation=90)
plt.yticks(range(len(columns)),columns)
plt.imshow(correlation, cmap='cool',interpolation="nearest")

# %%
columns = ["Team", "Points", "ORebs", "DRebs", "Assists", "Steals", "Blocks", "Turnovers", "3Point%", "FreeThrow%", "Win-Coefficient"]
plt.xticks(range(len(columns)),columns,rotation=90)
plt.yticks(range(len(columns)),columns)
plt.imshow(correlation, cmap='hot',interpolation="nearest")
